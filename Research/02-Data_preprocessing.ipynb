# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## Importing the data

# %%
file_path = 'Data\\job_descriptions.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#              Job Id     Experience Qualifications Salary Range   location  \
# 0  2008764324040548   1 to 9 Years         B.Tech    $55K-$96K       Bern
# 1   883214485661628  1 to 13 Years             BA    $55K-$92K  Stockholm
# 2  1312847636416093  3 to 11 Years         B.Tech   $55K-$127K       Male
# 3  1622354523422813  4 to 10 Years         B.Tech    $58K-$85K  New Delhi
# 4  2825294929394777  3 to 10 Years            MBA    $62K-$93K    Managua
#
#        Country  latitude  longitude  Work Type  Company Size  ...  \
# 0  Switzerland   46.8182     8.2275  Part-Time         85230  ...
# 1       Sweden   60.1282    18.6435   Contract        129985  ...
# 2     Maldives    3.2028    73.2207   Contract         24650  ...
# 3        India   20.5937    78.9629     Intern         52871  ...
# 4    Nicaragua   12.8654   -85.2072  Full-Time         96905  ...
#
#                   Contact               Job Title  \
# 0     (443)237-7206x52848     Project Coordinator
# 1  001-297-532-9394x30289  Procurement Specialist
# 2            796-496-2976       Software Engineer
# 3      (435)844-1435x1471    Marketing Specialist
# 4       767-322-6638x1919         Finance Manager
#
#                                Role           Job Portal  \
# 0  Construction Project Coordinator             LinkedIn
# 1           Procurement Coordinator         ZipRecruiter
# 2                Frontend Developer  Stack Overflow Jobs
# 3    Marketing Analytics Specialist                 Dice
# 4                Accounting Manager  Stack Overflow Jobs
#
#                                      Job Description  \
# 0  Construction Project Coordinators assist in ma...
# 1  Procurement Coordinators assist in procurement...
# 2  A Frontend Developer is responsible for design...
# 3  Marketing Analytics Specialists analyze market...
# 4  Accounting Managers supervise accounting teams...
#
#                                             Benefits  \
# 0  {'Transportation Benefits, Professional Develo...
# 1  {'Casual Dress Code, Social and Recreational A...
# 2  {'Life and Disability Insurance, Stock Options...
# 3  {'Flexible Spending Accounts (FSAs), Relocatio...
# 4  {'Tuition Reimbursement, Stock Options or Equi...
#
#                                               skills  \
# 0  Construction project management Building codes...
# 1  Procurement processes Purchase order managemen...
# 2  Proficiency in HTML, CSS, and JavaScript Exper...
# 3  Marketing analytics Data analysis Data visuali...
# 4  Accounting principles Financial reporting Team...
#
#                                     Responsibilities                Company  \
# 0  Coordinate construction projects, including pe...                    APA
# 1  Support procurement activities, such as purcha...            CSL Limited
# 2  Design and implement user interfaces for web a...            Haier Group
# 3  Analyze marketing data and generate insights t...  Brighthouse Financial
# 4  Manage accounting functions, including financi...              Starbucks
#
#                                      Company Profile
# 0  {"Sector":"Energy","Industry":"Mining, Crude-O...
# 1  {"Sector":"Pharmaceuticals","Industry":"Health...
# 2  {"Sector":"Appliances","Industry":"Electronics...
# 3  {"Sector":"Insurance","Industry":"Insurance: L...
# 4  {"Sector":"Food and Beverage","Industry":"Food...
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Identifying and handling missing value and duplicate value

# %%
missing_values = df.isnull().sum()
print("Missing Values:")
print(missing_values)
duplicate_rows = df.duplicated().sum()
print("\nDuplicate Rows:", duplicate_rows)
# Out:
# Missing Values:
# Job Id                 0
# Experience             0
# Qualifications         0
# Salary Range           0
# location               0
# Country                0
# latitude               0
# longitude              0
# Work Type              0
# Company Size           0
# Job Posting Date       0
# Preference             0
# Contact Person         0
# Contact                0
# Job Title              0
# Role                   0
# Job Portal             0
# Job Description        0
# Benefits               0
# skills                 0
# Responsibilities       0
# Company                0
# Company Profile     2394
# dtype: int64
#
# Duplicate Rows: 0

# %%
df = df.dropna(subset=['Company Profile']) #droping the column which has missing company profile (5478 Raws)

# %% [markdown]
# ##### Droping Unnecessary column

# %%
df = df.drop(columns=['Job Id', 'latitude', 'longitude', 'Contact Person', 'Contact', 'Job Portal', 'Benefits'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 696012 entries, 0 to 698405
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Experience        696012 non-null  object
#  1   Qualifications    696012 non-null  object
#  2   Salary Range      696012 non-null  object
#  3   location          696012 non-null  object
#  4   Country           696012 non-null  object
#  5   Work Type         696012 non-null  object
#  6   Company Size      696012 non-null  int64
#  7   Job Posting Date  696012 non-null  object
#  8   Preference        696012 non-null  object
#  9   Job Title         696012 non-null  object
#  10  Role              696012 non-null  object
#  11  Job Description   696012 non-null  object
#  12  skills            696012 non-null  object
#  13  Responsibilities  696012 non-null  object
#  14  Company           696012 non-null  object
#  15  Company Profile   696012 non-null  object
# dtypes: int64(1), object(15)
# memory usage: 90.3+ MB

# %% [markdown]
# ##### Extracting Min_experience and max_experience from experience and then droping the experience column

# %%
# Defining a function to process the experience range
def extract_experience(experience_range):
    # Removing 'years' and spliting by 'to'
    parts = experience_range.replace(' Years', '').split(' to ')
    
    # Converting to integer
    min_experience = int(parts[0])
    max_experience = int(parts[1])
    
    return min_experience, max_experience

# Apply the function to extract min and max experience
df[['min_experience', 'max_experience']] = df['Experience'].apply(lambda x: pd.Series(extract_experience(x)))

# Display the updated DataFrame
df.head()
# Out:
#       Experience Qualifications Salary Range   location      Country  \
# 0   1 to 9 Years         B.Tech    $55K-$96K       Bern  Switzerland
# 1  1 to 13 Years             BA    $55K-$92K  Stockholm       Sweden
# 2  3 to 11 Years         B.Tech   $55K-$127K       Male     Maldives
# 3  4 to 10 Years         B.Tech    $58K-$85K  New Delhi        India
# 4  3 to 10 Years            MBA    $62K-$93K    Managua    Nicaragua
#
#    Work Type  Company Size Job Posting Date Preference  \
# 0  Part-Time         85230       2023-01-11     Female
# 1   Contract        129985       2022-01-18       Both
# 2   Contract         24650       2022-04-08       Male
# 3     Intern         52871       2022-02-13     Female
# 4  Full-Time         96905       2021-12-13     Female
#
#                 Job Title                              Role  \
# 0     Project Coordinator  Construction Project Coordinator
# 1  Procurement Specialist           Procurement Coordinator
# 2       Software Engineer                Frontend Developer
# 3    Marketing Specialist    Marketing Analytics Specialist
# 4         Finance Manager                Accounting Manager
#
#                                      Job Description  \
# 0  Construction Project Coordinators assist in ma...
# 1  Procurement Coordinators assist in procurement...
# 2  A Frontend Developer is responsible for design...
# 3  Marketing Analytics Specialists analyze market...
# 4  Accounting Managers supervise accounting teams...
#
#                                               skills  \
# 0  Construction project management Building codes...
# 1  Procurement processes Purchase order managemen...
# 2  Proficiency in HTML, CSS, and JavaScript Exper...
# 3  Marketing analytics Data analysis Data visuali...
# 4  Accounting principles Financial reporting Team...
#
#                                     Responsibilities                Company  \
# 0  Coordinate construction projects, including pe...                    APA
# 1  Support procurement activities, such as purcha...            CSL Limited
# 2  Design and implement user interfaces for web a...            Haier Group
# 3  Analyze marketing data and generate insights t...  Brighthouse Financial
# 4  Manage accounting functions, including financi...              Starbucks
#
#                                      Company Profile  min_experience  \
# 0  {"Sector":"Energy","Industry":"Mining, Crude-O...               1
# 1  {"Sector":"Pharmaceuticals","Industry":"Health...               1
# 2  {"Sector":"Appliances","Industry":"Electronics...               3
# 3  {"Sector":"Insurance","Industry":"Insurance: L...               4
# 4  {"Sector":"Food and Beverage","Industry":"Food...               3
#
#    max_experience
# 0               9
# 1              13
# 2              11
# 3              10
# 4              10

# %%
df = df.drop(columns='Experience')

# %%
# Calculating the average experience
df['average_experience'] = df[['min_experience', 'max_experience']].mean(axis=1)

# %% [markdown]
# ##### Extracting min_salary and max_salary from salary_range and then droping the salary_range column

# %%
def extract_salary(salary_range):
    # Removing '$' and 'K', then spliting by '-'
    parts_salary = salary_range.replace('$', '').replace('K', '').split('-')
    
    # Converting to integers and multiplying by 1000
    min_salary = int(parts_salary[0]) * 1000
    max_salary = int(parts_salary[1]) * 1000
    
    return min_salary, max_salary

# Applying the function to extract min and max salary
df[['min_salary', 'max_salary']] = df['Salary Range'].apply(lambda x: pd.Series(extract_salary(x)))

# %%
df = df.drop(columns='Salary Range')
df['average_salary'] = df[['min_salary', 'max_salary']].mean(axis=1)
df.head()
# Out:
#   Qualifications   location      Country  Work Type  Company Size  \
# 0         B.Tech       Bern  Switzerland  Part-Time         85230
# 1             BA  Stockholm       Sweden   Contract        129985
# 2         B.Tech       Male     Maldives   Contract         24650
# 3         B.Tech  New Delhi        India     Intern         52871
# 4            MBA    Managua    Nicaragua  Full-Time         96905
#
#   Job Posting Date Preference               Job Title  \
# 0       2023-01-11     Female     Project Coordinator
# 1       2022-01-18       Both  Procurement Specialist
# 2       2022-04-08       Male       Software Engineer
# 3       2022-02-13     Female    Marketing Specialist
# 4       2021-12-13     Female         Finance Manager
#
#                                Role  \
# 0  Construction Project Coordinator
# 1           Procurement Coordinator
# 2                Frontend Developer
# 3    Marketing Analytics Specialist
# 4                Accounting Manager
#
#                                      Job Description  \
# 0  Construction Project Coordinators assist in ma...
# 1  Procurement Coordinators assist in procurement...
# 2  A Frontend Developer is responsible for design...
# 3  Marketing Analytics Specialists analyze market...
# 4  Accounting Managers supervise accounting teams...
#
#                                               skills  \
# 0  Construction project management Building codes...
# 1  Procurement processes Purchase order managemen...
# 2  Proficiency in HTML, CSS, and JavaScript Exper...
# 3  Marketing analytics Data analysis Data visuali...
# 4  Accounting principles Financial reporting Team...
#
#                                     Responsibilities                Company  \
# 0  Coordinate construction projects, including pe...                    APA
# 1  Support procurement activities, such as purcha...            CSL Limited
# 2  Design and implement user interfaces for web a...            Haier Group
# 3  Analyze marketing data and generate insights t...  Brighthouse Financial
# 4  Manage accounting functions, including financi...              Starbucks
#
#                                      Company Profile  min_experience  \
# 0  {"Sector":"Energy","Industry":"Mining, Crude-O...               1
# 1  {"Sector":"Pharmaceuticals","Industry":"Health...               1
# 2  {"Sector":"Appliances","Industry":"Electronics...               3
# 3  {"Sector":"Insurance","Industry":"Insurance: L...               4
# 4  {"Sector":"Food and Beverage","Industry":"Food...               3
#
#    max_experience  average_experience  min_salary  max_salary  average_salary
# 0               9                 5.0       55000       96000         75500.0
# 1              13                 7.0       55000       92000         73500.0
# 2              11                 7.0       55000      127000         91000.0
# 3              10                 7.0       58000       85000         71500.0
# 4              10                 6.5       62000       93000         77500.0

# %%
df['Job Posting Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 696012 entries, 0 to 698405
# Series name: Job Posting Date
# Non-Null Count   Dtype
# --------------   -----
# 696012 non-null  object
# dtypes: object(1)
# memory usage: 10.6+ MB

# %%
import pandas as pd
import re

irrelevant_words = [
    "knowledge", "and", "skills", "control", "including"
    "codes", "regulations", "cost", "monitor", "timelines",
    "assist", "in", "budgeting"
]

# Function to clean and extract skills
pattern = re.compile(r'\b(?:' + '|'.join(irrelevant_words) + r')\b', re.IGNORECASE)

# Function to clean and extract skills
def clean_skills(skills_string):
    # Remove brackets and their contents
    skills_string = re.sub(r'\[.*?\]|\(.*?\)|\{.*?\}', '', skills_string)
    
    # Clean the skills string by removing irrelevant words
    cleaned_skills = pattern.sub('', skills_string)
    
    # Split the cleaned string into a list of skills
    skill_list = re.split(r'\s*,\s*|\s+', cleaned_skills.strip())
    
    # Remove any empty strings from the list
    skill_list = [skill for skill in skill_list if skill]
    
    return skill_list

# Apply the function to the 'skills' column and generate the list of cleaned skills
df['skills'] = df['skills'].apply(clean_skills)

# %%
df['Job Posting Date'] = pd.to_datetime(df['Job Posting Date'])

# %%
df['Job Posting Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 696012 entries, 0 to 698405
# Series name: Job Posting Date
# Non-Null Count   Dtype
# --------------   -----
# 696012 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 10.6 MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 696012 entries, 0 to 698405
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Qualifications      696012 non-null  object
#  1   location            696012 non-null  object
#  2   Country             696012 non-null  object
#  3   Work Type           696012 non-null  object
#  4   Company Size        696012 non-null  int64
#  5   Job Posting Date    696012 non-null  datetime64[ns]
#  6   Preference          696012 non-null  object
#  7   Job Title           696012 non-null  object
#  8   Role                696012 non-null  object
#  9   Job Description     696012 non-null  object
#  10  skills              696012 non-null  object
#  11  Responsibilities    696012 non-null  object
#  12  Company             696012 non-null  object
#  13  Company Profile     696012 non-null  object
#  14  min_experience      696012 non-null  int64
#  15  max_experience      696012 non-null  int64
#  16  average_experience  696012 non-null  float64
#  17  min_salary          696012 non-null  int64
#  18  max_salary          696012 non-null  int64
#  19  average_salary      696012 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(12)
# memory usage: 111.5+ MB

# %%
df.to_csv("Data/cleaned_df.csv", index= False)
